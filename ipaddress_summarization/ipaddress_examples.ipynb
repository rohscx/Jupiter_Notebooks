172.31.255.93/32 
172.31.255.92/30 
172.31.255.113/32 
172.31.255.112/30 
172.31.255.117/32 
172.31.255.116/30 
172.31.255.121/32 
172.31.255.120/30 
172.31.255.129/32 
172.31.255.128/30 
172.31.255.133/32 
172.31.255.132/30 
172.31.255.141/32 
172.31.255.140/30 
172.31.255.169/32 
172.31.255.168/30 
172.31.255.172/30 
172.31.255.200/30 
172.31.255.217/32 
172.31.255.216/30 
172.31.255.240/30 
172.31.255.253/32 
172.31.255.252/30""".split("\n")
data2 = [x.strip() for x in data2]

# %%
data3 = [ipInspect(x, debug = {'status': False, 'level':0})["hosts"] for x in data2]

# %%
len(data3)
# Out:
# 1100

# %%
data4 = netaddr.cidr_merge(data2)

# %%
len(data4)
# Out:
# 481

# %%
temp = ipaddress.ip_network("10.100.100.0/30" , strict=False)
temp.hostmask
# Out:
# IPv4Address('0.0.0.3')

# %%
data5 = [ipInspect(str(x), debug = {'status': False, 'level':0}) for x in list(data4)]

# %%
data5[0:2]
# Out:
# [{'network_address': '10.10.21.0',
#   'broadcast_address': '10.10.21.255',
#   'prefix': 24,
#   'netmask': '255.255.255.0',
#   'host_range_begin': '10.10.21.1',
#   'host_range_end': '10.10.21.254',
#   'hosts': 256,
#   'hostmask': '0.0.0.255'},
#  {'network_address': '10.10.22.0',
#   'broadcast_address': '10.10.23.255',
#   'prefix': 23,
#   'netmask': '255.255.254.0',
#   'host_range_begin': '10.10.22.1',
#   'host_range_end': '10.10.23.254',
#   'hosts': 512,
#   'hostmask': '0.0.1.255'}]

# %%
data6 = "\n".join([f"{x['host_range_begin']} - {x['host_range_end']}" for x in data5])

# %%
# with open('./kdg_summarized_routes', 'x') as f:
#     f.write(data6)

# %%
data2.sort()

# %%
ipInspect("10.113.245.0/9", debug = {'status': False, 'level':0})
# Out:
# {'network_address': '10.0.0.0',
#  'broadcast_address': '10.127.255.255',
#  'prefix': 9,
#  'netmask': '255.128.0.0',
#  'host_range_begin': '10.0.0.1',
#  'host_range_end': '10.127.255.254',
#  'hosts': 8388608,
#  'hostmask': '0.127.255.255'}

# %%
ipInspect("50.205.227.192 255.255.255.224", debug = {'status': False, 'level':0})
# Out:
# {'network_address': '50.205.227.192',
#  'broadcast_address': '50.205.227.223',
#  'prefix': 27,
#  'netmask': '255.255.255.224',
#  'host_range_begin': '50.205.227.193',
#  'host_range_end': '50.205.227.222',
#  'hosts': 32,
#  'hostmask': '0.0.0.31'}

# %%
ipInspect("172.16.57.14 255.255.255.240", debug = {'status': False, 'level':0})
# Out:
# {'network_address': '172.16.57.0',
#  'broadcast_address': '172.16.57.15',
#  'prefix': 28,
#  'netmask': '255.255.255.240',
#  'host_range_begin': '172.16.57.1',
#  'host_range_end': '172.16.57.14',
#  'hosts': 16,
#  'hostmask': '0.0.0.15'}

# %%
ipInspect("192.168.32.0/20", debug = {'status': False, 'level':0})
# Out:
# {'network_address': '192.168.32.0',
#  'broadcast_address': '192.168.47.255',
#  'prefix': 20,
#  'netmask': '255.255.240.0',
#  'host_range_begin': '192.168.32.1',
#  'host_range_end': '192.168.47.254',
#  'hosts': 4096,
#  'hostmask': '0.0.15.255'}

# %%
ipInspect("10.172.0.0/15", subnets_prefix=26)
# Out:
# {'network_address': '10.172.0.0',
#  'broadcast_address': '10.173.255.255',
#  'prefix': 15,
#  'netmask': '255.254.0.0',
#  'host_range_begin': '10.172.0.1',
#  'host_range_end': '10.173.255.254',
#  'hosts': 131072,
#  'hostmask': '0.1.255.255',
#  'subnets': {'subnets_prefix': 26, 'subnets_count': 2048}}

# %%
ipInspect("50.235.180.96/27", subnets_prefix=30)
# Out:
# {'network_address': '50.235.180.96',
#  'broadcast_address': '50.235.180.127',
#  'prefix': 27,
#  'netmask': '255.255.255.224',
#  'host_range_begin': '50.235.180.97',
#  'host_range_end': '50.235.180.126',
#  'hosts': 32,
#  'hostmask': '0.0.0.31',
#  'subnets': {'subnets_prefix': 30, 'subnets_count': 8}}

# %%
ipInspect("50.235.180.96/30")
# Out:
# {'network_address': '50.235.180.96',
#  'broadcast_address': '50.235.180.99',
#  'prefix': 30,
#  'netmask': '255.255.255.252',
#  'host_range_begin': '50.235.180.97',
#  'host_range_end': '50.235.180.98',
#  'hosts': 4,
#  'hostmask': '0.0.0.3'}

# %%
ipInspect("50.235.180.131/27")
# Out:
# {'network_address': '50.235.180.128',
#  'broadcast_address': '50.235.180.159',
#  'prefix': 27,
#  'netmask': '255.255.255.224',
#  'host_range_begin': '50.235.180.129',
#  'host_range_end': '50.235.180.158',
#  'hosts': 32,
#  'hostmask': '0.0.0.31'}

# %%
ipInspect("107.191.114.191/255.255.255.128")
# Out:
# {'network_address': '107.191.114.128',
#  'broadcast_address': '107.191.114.255',
#  'prefix': 25,
#  'netmask': '255.255.255.128',
#  'host_range_begin': '107.191.114.129',
#  'host_range_end': '107.191.114.254',
#  'hosts': 128,
#  'hostmask': '0.0.0.127'}

# %%
ipaddress_is_subnet("107.191.114.32/28", "107.191.114.192/32")
# Out:
# False

# %%
ipaddress_is_subnet("107.191.114.128/25", "107.191.114.192/32")
# Out:
# True

# %%
ipaddress_is_subnet("172.20.208.0/20", "107.191.114.192/32")
# Out:
# False

# %%
data_m = """172.20.223.17/28   
172.20.223.33/28   
172.20.223.50/28   
172.20.223.66/28   
172.20.223.81/28""".split("\n")
data_m = [x.strip() for x in data_m]

# %%
[{"network":x, "result":ipaddress_is_subnet("172.20.208.0/20", x)} for x in data_m]
# Out:
# [{'network': '172.20.223.17/28', 'result': True},
#  {'network': '172.20.223.33/28', 'result': True},
#  {'network': '172.20.223.50/28', 'result': True},
#  {'network': '172.20.223.66/28', 'result': True},
#  {'network': '172.20.223.81/28', 'result': True}]

# %%
#https://docs.python.org/3/library/ipaddress.html#ip-network-definitions

# %%
# create a network

# %%
data.network_address
# Out:
# IPv4Address('10.100.100.0')

# %%
data.broadcast_address
# Out:
# IPv4Address('10.100.100.255')

# %%
data.hostmask
# Out:
# IPv4Address('0.0.0.255')

# %%
data.prefixlen
# Out:
# 24

# %%
data.netmask
# Out:
# IPv4Address('255.255.255.0')

# %%
# list all subnets in a supernet

# %%
print("Total number of /24 prefixes in: 172.16.0.0/12",len(list(ipaddress.ip_network('172.16.0.0/12').subnets(new_prefix=24))))
# Out:
# Total number of /24 prefixes in: 172.16.0.0/12 4096

# %%
print("Total number of /24 prefixes in: 10.0.0.0/8", len(list(ipaddress.ip_network('10.0.0.0/8').subnets(new_prefix=24))))
# Out:
# Total number of /24 prefixes in: 10.0.0.0/8 65536

# %%
print("Total number of /30 prefixes in 10.0.0.0/8:\n", len(list(ipaddress.ip_network('172.20.96.0/19').subnets(new_prefix=24))))
# Out:
# Total number of /30 prefixes in 10.0.0.0/8:
#  32

# %%
list(ipaddress.ip_network('172.20.64.0/18').subnets(new_prefix=24))[0]
# Out:
# IPv4Network('172.20.64.0/24')

# %%
print("\n\n".join([f"show ip route {str(x)} | i B E" for x in list(ipaddress.ip_network('10.242.0.0/16').subnets(new_prefix=26))]))
# Out:
# show ip route 10.242.0.0/26 | i B E
#
# show ip route 10.242.0.64/26 | i B E
#
# show ip route 10.242.0.128/26 | i B E
#
# show ip route 10.242.0.192/26 | i B E
#
# show ip route 10.242.1.0/26 | i B E
#
# show ip route 10.242.1.64/26 | i B E
#
# show ip route 10.242.1.128/26 | i B E
#
# show ip route 10.242.1.192/26 | i B E
#
# show ip route 10.242.2.0/26 | i B E
#
# show ip route 10.242.2.64/26 | i B E
#
# show ip route 10.242.2.128/26 | i B E
#
# show ip route 10.242.2.192/26 | i B E
#
# show ip route 10.242.3.0/26 | i B E
#
# show ip route 10.242.3.64/26 | i B E
#
# show ip route 10.242.3.128/26 | i B E
#
# show ip route 10.242.3.192/26 | i B E
#
# show ip route 10.242.4.0/26 | i B E
#
# show ip route 10.242.4.64/26 | i B E
#
# show ip route 10.242.4.128/26 | i B E
#
# show ip route 10.242.4.192/26 | i B E
#
# show ip route 10.242.5.0/26 | i B E
#
# show ip route 10.242.5.64/26 | i B E
#
# show ip route 10.242.5.128/26 | i B E
#
# show ip route 10.242.5.192/26 | i B E
#
# ...

# %%
# check if the address exists in the subnet

# %%
str(temp)
# Out:
# '172.20.64.0/24'

# %%
ipaddress.IPv4Address('50.235.180.135') in ipaddress.IPv4Network('50.235.180.128/27')
# Out:
# True

# %%
' '.join([
    "172.20.249.151",
    "172.20.249.153",
    "172.20.249.155",
    "172.20.249.163",
    "172.20.249.157",
    "172.20.249.174",
    "172.20.249.164",
    "172.20.249.178",
    "172.20.249.101",
    "172.20.249.102",
    "172.20.249.150",
    "172.20.249.152",
    "172.20.249.154",
    "172.20.249.162",
    "172.20.249.156",
    "172.20.249.158",
    "172.20.249.160",
    "172.20.249.161",
    "172.20.249.23",
    "172.20.249.24",
    "172.20.250.86",
    "172.20.250.83",
    "172.20.250.84",
    "172.20.250.98",
    "172.20.249.11",
    "172.20.249.12",
    "172.20.249.13",
    "172.20.249.14",
    "172.20.249.15",
    "172.20.249.16",
    "172.20.249.17",
    "172.20.249.18",
    "172.20.249.19",
    "172.20.249.20",
    "172.20.249.21",
    "172.20.249.22",
    "172.20.249.31",
    "172.20.249.32",
    "172.20.249.33",
    "172.20.249.34",
    "172.20.249.35",
    "172.20.249.36",
    "172.20.249.37",
    "172.20.249.38",
    "172.20.249.39",
    "172.20.249.40",
    "172.20.249.41",
    "172.20.249.42",
    "172.20.249.51",
    "172.20.249.52",
    "172.20.249.53",
    "172.20.249.54",
    "172.20.249.55",
    "172.20.249.56",
    "172.20.249.57",
    "172.20.249.62",
    "172.20.249.63",
    "172.20.249.64",
    "172.20.249.65",
    "172.20.249.66",
    "172.20.249.67"
]
)
# Out:
# '172.20.249.151 172.20.249.153 172.20.249.155 172.20.249.163 172.20.249.157 172.20.249.174 172.20.249.164 172.20.249.178 172.20.249.101 172.20.249.102 172.20.249.150 172.20.249.152 172.20.249.154 172.20.249.162 172.20.249.156 172.20.249.158 172.20.249.160 172.20.249.161 172.20.249.23 172.20.249.24 172.20.250.86 172.20.250.83 172.20.250.84 172.20.250.98 172.20.249.11 172.20.249.12 172.20.249.13 172.20.249.14 172.20.249.15 172.20.249.16 172.20.249.17 172.20.249.18 172.20.249.19 172.20.249.20 172.20.249.21 172.20.249.22 172.20.249.31 172.20.249.32 172.20.249.33 172.20.249.34 172.20.249.35 172.20.249.36 172.20.249.37 172.20.249.38 172.20.249.39 172.20.249.40 172.20.249.41 172.20.249.42 172.20.249.51 172.20.249.52 172.20.249.53 172.20.249.54 172.20.249.55 172.20.249.56 172.20.249.57 172.20.249.62 172.20.249.63 172.20.249.64 172.20.249.65 172.20.249.66 172.20.249.67'

# %%
import sys
from netaddr import IPAddress, cidr_merge

fh     = open ("./addresses.txt", 'r')
iplist = list()
for addr in fh:
    addr = IPAddress (addr.strip())
    iplist.append (addr)

fh.close()
print(cidr_merge (iplist))
import sys
from netaddr import IPAddress, cidr_merge

fh     = open (sys.argv[1], 'r')
iplist = list()
for addr in fh:
    addr = IPAddress (addr.strip())
    iplist.append (addr)

fh.close()
print(cidr_merge (iplist))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [4], line 7
#       5 iplist = list()
#       6 for addr in fh:
# ----> 7     addr = IPAddress (addr.strip())
#       8     iplist.append (addr)
#      10 fh.close()
#
# File /opt/conda/lib/python3.10/site-packages/netaddr/ip/__init__.py:278, in IPAddress.__init__(self, addr, version, flags)
#     275         raise ValueError('%r is an invalid IP version!' % version)
#     277 if _is_str(addr) and '/' in addr:
# --> 278     raise ValueError('%s() does not support netmasks or subnet' \
#     279         ' prefixes! See documentation for details.'
#     280         % self.__class__.__name__)
#     282 if self._module is None:
#     283     #   IP version is implicit, detect it from addr.
#     284     if isinstance(addr, _int_type):
#
# ...

# %%
# from netaddr import IPAddress, cidr_merge, IPv4Network
from ipaddress import IPv4Network
# list(ipaddress.summarize_address_range('192.0.2.0',[IPv4Network('192.0.2.0/25'), IPv4Network('192.0.2.128/31'), IPv4Network('192.0.2.130/32')]))

# %%
fh     = open ("./addresses.txt", 'r')
iplist = list()
for addr in fh:
    print(addr)
    addr = IPv4Network(addr.strip())
    iplist.append (addr)
# Out:
# 119.195.74.210/32
#
# 119.196.154.2/32
#
# 119.196.247.223/32
#
# 119.197.20.186/32
#
# 119.199.160.107/32
#
# 119.199.160.32/31
#
# 119.199.160.34/32
#
# 119.199.160.54/31
#
# 192.0.2.0/24
#
# 192.0.4.0/25
#
# 192.0.4.128/25

# %%
cidr_merge(iplist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_55/598315551.py in <module>
# ----> 1 cidr_merge(iplist)
#
# /opt/conda/lib/python3.9/site-packages/netaddr/ip/__init__.py in cidr_merge(ip_addrs)
#    1598             net = ip
#    1599         else:
# -> 1600             net = IPNetwork(ip)
#    1601         # Since non-overlapping ranges are the common case, remember the original
#    1602         ranges.append( (net.version, net.last, net.first, net) )
#
# /opt/conda/lib/python3.9/site-packages/netaddr/ip/__init__.py in __init__(self, addr, implicit_prefix, version, flags)
#     919         if hasattr(addr, '_prefixlen'):
#     920             #   IPNetwork object copy constructor
# --> 921             value = addr._value
#     922             module = addr._module
#     923             prefixlen = addr._prefixlen
#
# ...

# %%
IPAddress(iplist[0])
# Out:
# IPAddress('119.195.74.210')

# %%
fh = open ("./SFSDCE7ICR01.txt", 'r')

# %%
import re

drop_routes = ['0.0.0.0/0']

fh = open ("./SFSDCE7ICR01.txt", 'r')
targets = []
for new_line in fh:
    targets.extend(new_line.split(","))
targets = [x.strip() for x in targets[7:]]

regex = re.compile("^([0-9]{1,3}\.){3}[0-9]{1,3}(\/([0-9]|[1-2][0-9]|3[0-2]))?$")
targets = [x for x in targets if re.match(regex,x)]
targets = [x for x in targets if x not in drop_routes]
len(targets)
# Out:
# 395

# %%
summer_addresses = cidr_merge(targets[:])
len(summer_addresses)
# Out:
# 209

# %%
targets
# Out:
# ['10.1.60.0/24',
#  '10.1.60.1/32',
#  '10.1.60.3/32',
#  '10.1.109.0/24',
#  '10.1.109.1/32',
#  '10.1.109.3/32',
#  '10.1.110.0/24',
#  '10.1.110.1/32',
#  '10.1.110.3/32',
#  '10.1.111.0/24',
#  '10.1.111.1/32',
#  '10.1.111.3/32',
#  '10.1.112.0/24',
#  '10.1.112.1/32',
#  '10.1.112.3/32',
#  '10.1.115.0/24',
#  '10.1.115.1/32',
#  '10.1.115.3/32',
#  '10.1.116.0/24',
#  '10.1.116.1/32',
#  '10.1.116.3/32',
#  '10.1.120.0/24',
#  '10.1.120.1/32',
#  '10.1.120.3/32',
#  '10.1.121.0/24',
#  '10.1.121.1/32',
#  '10.1.121.3/32',
#  '10.1.122.0/24',
#  '10.1.122.1/32',
#  '10.1.122.3/32',
#  '10.1.123.0/24',
#  '10.1.123.1/32',
#  '10.1.123.3/32',
#  '10.1.124.0/24',
#  '10.1.124.1/32',
#  '10.1.124.3/32',
#  '10.1.125.0/24',
#  '10.1.125.1/32',
#  '10.1.125.3/32',
#  '10.1.126.0/24',
#  '10.1.126.1/32',
#  '10.1.126.3/32',
#  '10.1.127.0/24',
#  '10.1.127.1/32',
#  '10.1.127.3/32',
#  '10.1.128.0/24',
#  '10.1.128.1/32',
#  '10.1.128.3/32',
#  '10.1.129.0/24',
#  '10.1.129.1/32',
# ...

# %%
[str(x) for x in summer_addresses]
# Out:
# ['10.1.60.0/24',
#  '10.1.109.0/24',
#  '10.1.110.0/23',
#  '10.1.112.0/24',
#  '10.1.115.0/24',
#  '10.1.116.0/24',
#  '10.1.120.0/21',
#  '10.1.128.0/21',
#  '10.1.150.0/23',
#  '10.1.152.0/24',
#  '10.1.190.0/23',
#  '10.1.192.0/24',
#  '10.1.199.0/24',
#  '10.1.200.0/24',
#  '10.1.202.0/23',
#  '10.1.204.0/23',
#  '10.1.206.0/24',
#  '10.1.220.0/24',
#  '10.1.222.0/24',
#  '10.1.224.0/23',
#  '10.2.0.0/16',
#  '10.4.0.0/16',
#  '10.7.0.0/16',
#  '10.10.0.0/24',
#  '10.11.0.0/16',
#  '10.16.0.0/16',
#  '10.18.0.0/16',
#  '10.24.0.0/14',
#  '10.29.0.0/16',
#  '10.33.0.0/16',
#  '10.50.175.100/32',
#  '10.66.128.16/28',
#  '10.100.0.0/24',
#  '10.100.2.0/24',
#  '10.100.4.0/24',
#  '10.100.10.192/26',
#  '10.100.11.0/24',
#  '10.100.13.0/24',
#  '10.100.14.0/23',
#  '10.100.16.0/24',
#  '10.100.31.0/24',
#  '10.100.32.0/24',
#  '10.100.34.0/24',
#  '10.100.36.0/24',
#  '10.100.51.4/30',
#  '10.100.51.8/30',
#  '10.100.51.16/28',
#  '10.100.51.32/28',
#  '10.100.255.0/26',
# ...

# %%
data_test = """10.12.100.101
10.248.1.2
10.12.0.2
10.100.31.29
10.248.1.11
10.12.100.100
10.100.51.17
10.248.1.14
50.235.180.131
10.248.1.1
10.248.1.22
10.100.31.28
10.248.1.12
10.100.31.38
10.100.31.39
10.100.31.41
10.100.31.11
10.100.31.40
10.100.31.43
10.100.31.98
10.100.31.42
10.248.1.3
10.248.1.4
10.12.0.129
10.12.0.154
10.12.0.157""".split('\n')

# %%
cidr_merge(data_test)
# Out:
# [IPNetwork('10.12.0.2/32'),
#  IPNetwork('10.12.0.129/32'),
#  IPNetwork('10.12.0.154/32'),
#  IPNetwork('10.12.0.157/32'),
#  IPNetwork('10.12.100.100/31'),
#  IPNetwork('10.100.31.11/32'),
#  IPNetwork('10.100.31.28/31'),
#  IPNetwork('10.100.31.38/31'),
#  IPNetwork('10.100.31.40/30'),
#  IPNetwork('10.100.31.98/32'),
#  IPNetwork('10.100.51.17/32'),
#  IPNetwork('10.248.1.1/32'),
#  IPNetwork('10.248.1.2/31'),
#  IPNetwork('10.248.1.4/32'),
#  IPNetwork('10.248.1.11/32'),
#  IPNetwork('10.248.1.12/32'),
#  IPNetwork('10.248.1.14/32'),
#  IPNetwork('10.248.1.22/32'),
#  IPNetwork('50.235.180.131/32')]
